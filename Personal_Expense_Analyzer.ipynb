# %%
# 💰 Personal Expense Analyzer

A beginner Python project for analyzing personal expenses.

# %%
expenses = {
    "Food": [500, 250],
    "Transport": [300, 200],
    "Education": [1000],
    "Shopping": [800]
}
